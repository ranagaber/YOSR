# %%
import os
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import camel_tools 
from camel_tools.utils.normalize import normalize_unicode
from camel_tools.utils.normalize import normalize_alef_maksura_ar
from camel_tools.utils.normalize import normalize_alef_ar
from camel_tools.utils.normalize import normalize_teh_marbuta_ar
from camel_tools.utils.dediac import dediac_ar
import textstat
import time
import os
from huggingface_hub import HfApi, hf_hub_download

# %%
df = pd.read_csv("gemma-3n-E4B_Curr_Egy_outputs_fixed.csv")

# %%
df.head()
# Out:
#      lecture             image_name  \
# 0  CHI-91486  CHI-91486-0010000.jpg
# 1  CHI-91486  CHI-91486-0047450.jpg
# 2  CHI-91486  CHI-91486-0077450.jpg
# 3  CHI-91486  CHI-91486-0111450.jpg
# 4  CHI-91486  CHI-91486-0123450.jpg
#
#                                               output
# 0  عايز اشرحلك الشريحه دي؟ الشريحه دي عنوانها Cro...
# 1  عايزين نتكلم عن الخلفيه اللي احنا بنحاول نفهمه...
# 2  عايز اشرحلك الشريحه دي اللي بتتكلم عن التكيف ا...
# 3  عايز اشرحلك الشريحه دي اللي بتتكلم عن ال Crowd...
# 4  عايز اشرحلك الصوره دي اللي فيها شرح لعمليه الت...

# %%
#cleaning before evaluation 
def clean(df , col):
    '''
    The input should be the df itself + the column name that contains the text data.
    '''
    #df = df.drop_duplicates(subset=[col])
    #df = df.dropna(subset=[col])

    
    df = df.reset_index(drop=True)
    df[col] = df[col].fillna("").astype(str)
    for i in range(len(df)):
        sentence = df.loc[i, col]
        sentence = normalize_unicode(sentence)
        sentence = dediac_ar(sentence)
        sentence = normalize_alef_maksura_ar(sentence)
        sentence = normalize_alef_ar(sentence)
        sentence = normalize_teh_marbuta_ar(sentence)
        #instead of removing english we keep it so its penalized for english usage
        #this regex will remove all non-Arabic letters and non-space characters
        #sentence = re.sub(r'[^\u0600-\u06FF\s]', '', sentence, flags=re.UNICODE)
        df.loc[i , col] = sentence
    return df

# %%
df.columns
# Out:
# Index(['lecture', 'image_name', 'output'], dtype='object')

# %%
df = clean(df , 'output')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   lecture     1067 non-null   object
#  1   image_name  1067 non-null   object
#  2   output      1067 non-null   object
# dtypes: object(3)
# memory usage: 25.1+ KB

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1114 entries, 0 to 1113
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   lecture  1114 non-null   object
#  1   image    1114 non-null   object
#  2   source   1114 non-null   object
#  3   aya      1114 non-null   object
#  4   qwen     1114 non-null   object
#  5   ain      1114 non-null   object
#  6   gemma    1114 non-null   object
# dtypes: object(7)
# memory usage: 61.1+ KB

# %%
df = df.rename(columns = {'image_name' : 'image'})

# %%
df = df.merge(b[['image', 'source']], on='image', how='left')

# %%
df
# Out:
#         lecture                  image  \
# 0     CHI-91486  CHI-91486-0010000.jpg
# 1     CHI-91486  CHI-91486-0047450.jpg
# 2     CHI-91486  CHI-91486-0077450.jpg
# 3     CHI-91486  CHI-91486-0111450.jpg
# 4     CHI-91486  CHI-91486-0123450.jpg
# ...         ...                    ...
# 1062  CHI-214E5  CHI-214E5-0215000.jpg
# 1063  CHI-214E5  CHI-214E5-0231450.jpg
# 1064  CHI-214E5  CHI-214E5-0244450.jpg
# 1065  CHI-214E5  CHI-214E5-0260450.jpg
# 1066  CHI-214E5  CHI-214E5-0293000.jpg
#
#                                                  output  \
# 0     عايز اشرحلك الشريحه دي؟ الشريحه دي عنوانها Cro...
# 1     عايزين نتكلم عن الخلفيه اللي احنا بنحاول نفهمه...
# 2     عايز اشرحلك الشريحه دي اللي بتتكلم عن التكيف ا...
# 3     عايز اشرحلك الشريحه دي اللي بتتكلم عن ال Crowd...
# 4     عايز اشرحلك الصوره دي اللي فيها شرح لعمليه الت...
# ...                                                 ...
# 1062  عايزين نتكلم عن الكي لوينج كومبيتينسيز اللي هي...
# 1063  عايزين نشوف ايه الفرق بين Zoom و RobotAR في تق...
# 1064  عن التعليقات اللي في الردود في الردود في الردو...
# 1065  الاساتذه كان عندهم وصول احسن ل مكان الطلاب و م...
# 1066  الاسليد دي هي الخلاصه بتاعته و فيها النقاط الا...
#
#                                                  source
# 0     أهلاً، وشكراً لاهتمامكم بورقتنا البحثية عن الا...
# 1     محتوى النصوص في الواقع المعزز (AR). الواقع الم...
# 2     السياق المادي. وعشان نخلي بحثنا ملموس، ركزنا ع...
# 3     دراستهم القايمة على المعمل. وعشان نسرع وضع إرش...
# 4     الهدف هو جمع ملاحظات المستخدمين على مجموعة متن...
# ...                                                 ...
# 1062  اختبرنا الطلاب باستخدام اختبارات قبلية وبعدية،...
# 1063  أكملوا خاصتهم. وبالمثل، باستخدام الواقع المعزز...
# 1064  فدي كانت أبرز النقط من دراسات المستخدمين دي. م...
# 1065  المدربين كمان بلغوا إنهم بقوا قادرين يقدموا تو...
# 1066  عشان نقفل المشروع ده، عايز أسيب النقط الأساسية...
#
# [1067 rows x 4 columns]

# %%
b = pd.read_csv('baseline_outputs.csv')
b.head()
# Out:
#      lecture                  image  \
# 0  CHI-01C34  CHI-01C34-0339000.jpg
# 1  CHI-01C34  CHI-01C34-0169000.jpg
# 2  CHI-01C34  CHI-01C34-0020000.jpg
# 3  CHI-01C34  CHI-01C34-0126000.jpg
# 4  CHI-01C34  CHI-01C34-0207000.jpg
#
#                                               source  \
# 0  الأساس المنطقي للحدود دي. وبالنيابة عن زملائي ...
# 1  أثناء استخدام التطبيق. برز موضوعين شاملين في ن...
# 2  أهلاً، اسمي صبا قواس وأنا طالبة دكتوراه في جام...
# 3  توترات. سألنا السؤال التالي: إزاي الأهالي بيخت...
# 4  استخدام التكنولوجيا كمرحلة انتقالية. أهالي كتي...
#
#                                                  aya  \
# 0  عندما وقت الشاشة ليس وقت الشاشة\n\nتوترات واحت...
# 1  هذه الشريحة تعرض نتائج دراسة حول استخدام تطبيق...
# 2  عندما وقت الشاشة ليس وقت الشاشة: التوترات والا...
# 3  هذه الشريحة تتناول أسئلة البحث المتعلقة بتطبيق...
# 4  عائلات' تجارب استخدام تطبيق تينز خلال استكشاف ...
#
#                                                 qwen  \
# 0  هذا الشرائح يتكلم عن موضوع: "عندما يكون وقت ال...
# 1  هذا الشرائح بيقول:\n\n**نتائج الدراسة**\n\n(1)...
# 2  هذا الشرائح بعنوان: "عندما يكون وقت الشاشة ليس...
# 3  هذا الشرائح بعنوان "أسئلة البحث" وده مكتوب بخط...
# 4  هذا الشرائح عن تجربة العائلات في استخدام تطبيق...
#
#                                                  ain  \
# 0  أهلاً بكم في هذه الشريحة عن وقت الشاشة. إنها ع...
# 1  مرحباً يا طلاب! دعنا نتحدث عن هذه الشريحة.\n\n...
# 2  أهلاً بكم، أصدقائي! دعونا نتحدث عن هذه الشريحة...
# 3  مرحبا يا طلاب! دعنا نتحدث عن هذه الشريحة.\n\nا...
# 4  مرحبا يا طلاب! دعنا نتحدث عن هذه الشريحة عن تج...
#
#                                                gemma
# 0  أهلاً بك يا بني! هذه الشريحة من عرض تقديمي. خل...
# 1  أهلاً بك يا بني! هذه الشريحة من عرض نتائج دراس...
# 2  أهلاً بك يا بني! هذه شريحة من عرض تقديمي. دعني...
# 3  أهلاً بك يا بني! هذه الشريحة تتحدث عن أسئلة ال...
# 4  أهلاً بك يا بني/يا بنتي، سأشرح لك هذه الشريحة ...

# %%
import evaluate
from bert_score import score
import numpy as np
import bert_score


meteor = evaluate.load("meteor")       
bleu = evaluate.load("bleu")          
chrf = evaluate.load("chrf")         
bleurt = evaluate.load("bleurt")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /teamspace/studios/this_studio/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# Downloading builder script: 0.00B [00:00, ?B/s]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777645221.739590   89326 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1777645221.949104   89326 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1777645223.199351   89326 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Using default checkpoint 'bleurt-base-128' for sequence maximum length 128. You can use a bigger model for better results with e.g.: evaluate.load('bleurt', config_name='bleurt-large-512').
# Downloading data:   0%|          | 0.00/405M [00:00<?, ?B/s]
# INFO:tensorflow:Reading checkpoint /teamspace/studios/this_studio/.cache/huggingface/metrics/bleurt/default/downloads/extracted/c9567476201aa8527ea010c5ce7f3b534bd6d445678239cb4a0c4147530e5f31/bleurt-base-128.
# INFO:tensorflow:Config file found, reading.
# INFO:tensorflow:Will load checkpoint bert_custom
# INFO:tensorflow:Loads full paths and checks that files exists.
# INFO:tensorflow:... name:bert_custom
# INFO:tensorflow:... vocab_file:vocab.txt
# INFO:tensorflow:... bert_config_file:bert_config.json
# INFO:tensorflow:... do_lower_case:True
# INFO:tensorflow:... max_seq_length:128
# INFO:tensorflow:Creating BLEURT scorer.
# INFO:tensorflow:Creating WordPiece tokenizer.
# INFO:tensorflow:WordPiece tokenizer instantiated.
# INFO:tensorflow:Creating Eager Mode predictor.
# INFO:tensorflow:Loading model.
# W0000 00:00:1777645241.414816   89326 gpu_device.cc:2365] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# INFO:tensorflow:BLEURT initialized.
# INFO:tensorflow:BLEURT initialized.

# %%
#!pip install nltk
#!pip install sacrebleu
#!pip install git+https://github.com/google-research/bleurt.git
# Out:
# Collecting git+https://github.com/google-research/bleurt.git
#   Cloning https://github.com/google-research/bleurt.git to /tmp/pip-req-build-j2hr4q0p
#   Running command git clone --filter=blob:none --quiet https://github.com/google-research/bleurt.git /tmp/pip-req-build-j2hr4q0p
#
#   Resolved https://github.com/google-research/bleurt.git to commit cebe7e6f996b40910cfaa520a63db47807e3bf5c
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: pandas in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from BLEURT==0.0.2) (2.1.4)
# Requirement already satisfied: numpy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from BLEURT==0.0.2) (1.26.4)
# Requirement already satisfied: scipy in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from BLEURT==0.0.2) (1.11.4)
# Collecting tensorflow (from BLEURT==0.0.2)
#   Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl.metadata (4.4 kB)
# Collecting tf-slim>=1.1 (from BLEURT==0.0.2)
#   Downloading tf_slim-1.1.0-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sentencepiece in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from BLEURT==0.0.2) (0.2.1)
# Requirement already satisfied: absl-py>=0.2.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tf-slim>=1.1->BLEURT==0.0.2) (2.4.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->BLEURT==0.0.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->BLEURT==0.0.2) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from pandas->BLEURT==0.0.2) (2025.3)
# Requirement already satisfied: six>=1.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->BLEURT==0.0.2) (1.17.0)
# Collecting astunparse>=1.6.0 (from tensorflow->BLEURT==0.0.2)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow->BLEURT==0.0.2)
#   Downloading flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow->BLEURT==0.0.2)
#   Downloading gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow->BLEURT==0.0.2)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow->BLEURT==0.0.2)
#   Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow->BLEURT==0.0.2)
#   Downloading opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tensorflow->BLEURT==0.0.2) (25.0)
# Requirement already satisfied: protobuf<8.0.0,>=6.31.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tensorflow->BLEURT==0.0.2) (7.34.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tensorflow->BLEURT==0.0.2) (2.32.5)
# Requirement already satisfied: setuptools in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tensorflow->BLEURT==0.0.2) (80.10.2)
# Collecting termcolor>=1.1.0 (from tensorflow->BLEURT==0.0.2)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tensorflow->BLEURT==0.0.2) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow->BLEURT==0.0.2)
#   Downloading wrapt-2.1.2-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from tensorflow->BLEURT==0.0.2) (1.78.0)
# Collecting keras>=3.12.0 (from tensorflow->BLEURT==0.0.2)
#   Downloading keras-3.14.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow->BLEURT==0.0.2)
#   Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow->BLEURT==0.0.2)
#   Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->BLEURT==0.0.2) (2026.2.25)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->BLEURT==0.0.2) (0.46.3)
# Requirement already satisfied: rich in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from keras>=3.12.0->tensorflow->BLEURT==0.0.2) (14.3.3)
# Collecting namex (from keras>=3.12.0->tensorflow->BLEURT==0.0.2)
#   Downloading namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow->BLEURT==0.0.2)
#   Downloading optree-0.19.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (34 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow->BLEURT==0.0.2) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from rich->keras>=3.12.0->tensorflow->BLEURT==0.0.2) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /home/zeus/miniconda3/envs/cloudspace/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow->BLEURT==0.0.2) (0.1.2)
# Downloading tf_slim-1.1.0-py2.py3-none-any.whl (352 kB)
# Downloading tensorflow-2.21.0-cp312-cp312-manylinux_2_27_x86_64.whl (572.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 91.4 MB/s  0:00:04m0:00:0100:01
# Downloading h5py-3.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 11.9 MB/s  0:00:00 eta 0:00:01
# Downloading ml_dtypes-0.5.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 265.4 MB/s  0:00:00
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Downloading gast-0.7.0-py3-none-any.whl (22 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading keras-3.14.0-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 139.9 MB/s  0:00:00
# Downloading libclang-18.1.1-py2.py3-none-manylinux2010_x86_64.whl (24.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.5/24.5 MB 141.6 MB/s  0:00:00
# Downloading opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.1.2-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (121 kB)
# Downloading namex-0.1.0-py3-none-any.whl (5.9 kB)
# Downloading optree-0.19.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (451 kB)
# Building wheels for collected packages: BLEURT
#   Building wheel for BLEURT (pyproject.toml) ... done
#   Created wheel for BLEURT: filename=bleurt-0.0.2-py3-none-any.whl size=16456845 sha256=c363de80085229999a5b3f5584c6545aca95e9890c3d0edf4abe217ab53f30fc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2b0fz3kv/wheels/7d/7d/6a/b06f2c763c081f3de412125c1e0bcbc941dc14da222f7c4273
# Successfully built BLEURT
# Installing collected packages: namex, libclang, flatbuffers, wrapt, tf-slim, termcolor, optree, opt_einsum, ml_dtypes, h5py, google_pasta, gast, astunparse, keras, tensorflow, BLEURT
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [BLEURT]15/16 [BLEURT]low]
# Successfully installed BLEURT-0.0.2 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 h5py-3.14.0 keras-3.14.0 libclang-18.1.1 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.0 tensorflow-2.21.0 termcolor-3.3.0 tf-slim-1.1.0 wrapt-2.1.2

# %%
references = df['source'].tolist()
predictions = df["output"].tolist()

# %%
# computationally expenisive to an extent
from transformers import AutoTokenizer, AutoModelForSequenceClassification
model_name = "AMR-KELEG/Sentence-ALDi"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForSequenceClassification.from_pretrained(model_name)

def compute_aldi(predictions):
    sum = 0
    for p in predictions:
        inputs = tokenizer(p, return_tensors="pt")
        outputs = model(**inputs)
        logits = outputs.logits
        sum += min(max(0, logits[0][0].item()), 1)
    mean  = sum / len(predictions)
    return mean
# Out:
# config.json:   0%|          | 0.00/978 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/376 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/651M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# model.safetensors:   0%|          | 0.00/651M [00:00<?, ?B/s]

# %%
meteor_score = meteor.compute(predictions=predictions, references=references)
print("METEOR:", meteor_score)

bleu_score = bleu.compute(predictions=predictions, references=references)
print("BLEU:", bleu_score)

chrf_score = chrf.compute(predictions=predictions, references=references)
print("CHRF+:", chrf_score)


bleurt_score = bleurt.compute(predictions=predictions, references=references)
print("BLEURT:", np.mean(bleurt_score['scores']))

P, R, F1 = bert_score.score(predictions, references, lang="ar", verbose=True)

print("Bert score Precision:", P.mean().item())
print("Bert score Recall:", R.mean().item())
print("Bert score F1:", F1.mean().item())
# Out:
# METEOR: {'meteor': 0.04257492785950839}
# BLEU: {'bleu': 0.002498637961256573, 'precisions': [0.05244224522631371, 0.005399984571472653, 0.0008627586315079453, 0.00015953288770480034], 'brevity_penalty': 1.0, 'length_ratio': 1.1792439321257249, 'translation_length': 65882, 'reference_length': 55868}
# CHRF+: {'score': 13.168198422533294, 'char_order': 6, 'word_order': 0, 'beta': 2}
# BLEURT: -0.28662288350235554
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# [transformers] BertModel LOAD REPORT from: bert-base-multilingual-cased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# calculating scores...
# computing bert embedding.
#   0%|          | 0/34 [00:00<?, ?it/s]
# computing greedy matching.
#   0%|          | 0/17 [00:00<?, ?it/s]
# done in 2.64 seconds, 404.80 sentences/sec
# Bert score Precision: 0.6200234293937683
# Bert score Recall: 0.6333864331245422
# Bert score F1: 0.6245044469833374

# %%
#Readability
import textstat
scores = [textstat.osman(p) for p in predictions]
print("Readability score: " , np.mean(scores))
# Out:
# Readability score:  44.96419532216988

# %%
ALDI = compute_aldi(predictions)
print("ALDI score:" , ALDI)
# Out:
# ALDI score: 0.4664724903583139
